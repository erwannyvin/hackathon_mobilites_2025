# %%
from utils.loader_local import LoaderLocal
import geopandas as gpd
import pandas as pd

# %%
df_final = LoaderLocal.loader_geoparquet("/home/onyxia/work/hackathon_mobilites_2025/data/enrich/final_table.gpq")
df_corr = LoaderLocal.loader_parquet("/home/onyxia/work/hackathon_mobilites_2025/data/metro_conexion_qualif.parquet")

# %%
# Out:
# Empty GeoDataFrame
# Columns: [geo_point_2d, id_ref_zdc, nom_zda, station_clean, res_com, mode, exploitant, geometry, ligne, station, facilite_acces_code, facilite_acces, nombre_facilite_acces_station, id_zdc, total_validation, total_validation_amethyste, pct_amethyste]
# Index: []
